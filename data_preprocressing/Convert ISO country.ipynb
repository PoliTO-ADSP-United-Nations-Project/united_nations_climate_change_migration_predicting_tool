# %%
# !pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pycountry) (57.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=c283ce0853febd4dc49a5818fb171d16ce408fddcee40ec814de01b7de5f2fcf
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
import pycountry

# %%
print(pycountry.countries.get(alpha_3='SLE'))
# Out:
# Country(alpha_2='SL', alpha_3='SLE', flag='🇸🇱', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone')

# %%
my_ISO_list = ['OOS',
'MAR',
'DZA',
'MLI',
'BFA',
'GIN',
'SYR',
'EGY',
'CIV',
'GMB',
'LBR',
'LBY',
'SDN',
'SEN',
'TUN',
'PSE',
'SLE',
'BGD',
'CAF',
'ZAF',
'CMR',
'ERI',
'GNB',
'NGA',
'TCD',
'YEM',
'IRQ',
'LBN',
'TGO',
'BEN',
'GAB',
'NER',
'PAK',
'ETH']

# %%
my_country = [pycountry.countries.get(alpha_3=iso) for iso in my_ISO_list]

# %%
none_list = []
for i in range(len(my_country)):
  country = my_country[i]
  if country is None:
    none_list.append(i)

for index in none_list:
  print("Unknown: " + my_ISO_list[index])
  my_country[index] = ''
# Out:
# Unknown: OOS

# %%
for country in my_country:
  if isinstance(country, str):
    print(country)
  else:
    print(country.name)
# Out:
# Morocco
# Algeria
# Mali
# Burkina Faso
# Guinea
# Syrian Arab Republic
# Egypt
# Côte d'Ivoire
# Gambia
# Liberia
# Libya
# Sudan
# Senegal
# Tunisia
# Palestine, State of
# Sierra Leone
# Bangladesh
# Central African Republic
# South Africa
# Cameroon
# Eritrea
# Guinea-Bissau
# Nigeria
# Chad
# Yemen
# Iraq
# Lebanon
# Togo
# Benin
# Gabon
# Niger
# Pakistan
# Ethiopia
